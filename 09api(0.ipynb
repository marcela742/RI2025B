# %% [markdown]
# Nombre: Marcela Cabrera

# %% [markdown]
# # Ejercicio 9: Uso de la API de Google Gemini
#
# En este ejercicio vamos a aprender a utilizar la API de OpenAI
#
# ## 1. Uso básico
#
# El siguiente código sirve para conectarse con la API de Google Gemini de forma básica

# %%
import google.generativeai as genai

# Leer la API key desde un archivo de texto
with open('api-key.txt', 'r') as file:
    api_key = file.read().strip()

# Configurar la API de Google Gemini
genai.configure(api_key=api_key)

# Crear el modelo (usando el más reciente y estable)
model = genai.GenerativeModel('gemini-2.5-flash')

# %% [markdown]
# ## 2. Retrieval

# %% [markdown]
# ### 2.1 Cargo el corpus de 20 News Groups

# %%
from sklearn.datasets import fetch_20newsgroups

# Cargar el corpus de noticias sin cabeceras, pies de página y citas
newsgroups = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))
docs = newsgroups.data
df = pd.DataFrame(docs, columns=['doc'])
df.head(10)
# Out:
#                                                  doc
# 0  \n\nI am sure some bashers of Pens fans are pr...
# 1  My brother is in the market for a high-perform...
# 2  \n\n\n\n\tFinally you said what you dream abou...
# 3  \nThink!\n\nIt's the SCSI card doing the DMA t...
# 4  1)    I have an old Jasmine drive which I cann...
# 5  \n\nBack in high school I worked as a lab assi...
# 6  \n\nAE is in Dallas...try 214/241-6060 or 214/...
# 7  \n[stuff deleted]\n\nOk, here's the solution t...
# 8  \n\n\nYeah, it's the second one.  And I believ...
# 9  \nIf a Christian means someone who believes in...

# %% [markdown]
# ### 2.2 Transformo a embeddings

# %% [markdown]
# 1.  Normalizar el corpus

# %%
import pandas as pd
import numpy as np
from tqdm.auto import tqdm
import re

df = df.dropna(subset=["doc"]).reset_index(drop=True)

# Limpieza básica
def normalize_text(s: str) -> str:
    s = re.sub(r"\s+", " ", s).strip()
    return s

df["doc_norm"] = df["doc"].astype(str).map(normalize_text)

df.head()
# Out:
#                                                  doc  \
# 0  \n\nI am sure some bashers of Pens fans are pr...
# 1  My brother is in the market for a high-perform...
# 2  \n\n\n\n\tFinally you said what you dream abou...
# 3  \nThink!\n\nIt's the SCSI card doing the DMA t...
# 4  1)    I have an old Jasmine drive which I cann...
#
#                                             doc_norm
# 0  I am sure some bashers of Pens fans are pretty...
# 1  My brother is in the market for a high-perform...
# 2  Finally you said what you dream about. Mediter...
# 3  Think! It's the SCSI card doing the DMA transf...
# 4  1) I have an old Jasmine drive which I cannot ...

# %% [markdown]
# 2. Definir una función chunk_text, y dividir los textos en chunks.

# %%
def chunk_doc(doc: str, max_chars: int = 800, overlap: int = 100):

    chunks = []
    start = 0
    n = len(doc)
    while start < n:
        end = min(start + max_chars, n)
        chunk = doc[start:end]
        chunk = chunk.strip()
        if len(chunk) > 0:
            chunks.append(chunk)
        if end == n:
            break
        start = max(0, end - overlap)
    return chunks

records = []
for i, row in df.iterrows():
    chunks = chunk_doc(row["doc_norm"], max_chars=800, overlap=100)
    for j, ch in enumerate(chunks):
        records.append({
            "doc_id": int(i),
            "chunk_id": j,
            "text": ch
        })

chunks_df = pd.DataFrame(records)
chunks_df.head(), len(chunks_df)
# Out:
# (   doc_id  chunk_id                                               text
#  0       0         0  I am sure some bashers of Pens fans are pretty...
#  1       1         0  My brother is in the market for a high-perform...
#  2       2         0  Finally you said what you dream about. Mediter...
#  3       2         1  urds and Turks once upon a time! Ohhhh so swed...
#  4       3         0  Think! It's the SCSI card doing the DMA transf...,
#  38871)

# %%
from sentence_transformers import SentenceTransformer

MODEL_NAME = "intfloat/e5-base-v2"   # recomendado para retrieval
model = SentenceTransformer(MODEL_NAME)

# Textos a indexar (pasajes)
passages = ["passage: " + t for t in chunks_df["text"].tolist()]
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# ,The secret `HF_TOKEN` does not exist in your Colab secrets.
# ,To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# ,You will be able to reuse this secret in all of your notebooks.
# ,Please note that authentication is recommended but still optional to access public models or datasets.
# ,  warnings.warn(
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/650 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]

# %%
# Embeddings (N x D)
# Se debe usar normalize_embeddings=True para similitud coseno
embeddings = model.encode(
    passages,
    batch_size=16,
    show_progress_bar=True,
    convert_to_numpy=True,
    normalize_embeddings=True
).astype("float32")
# Out:
# Batches:   0%|          | 0/2430 [00:00<?, ?it/s]

# %% [markdown]
# ### 2.3 Creo una query y hago la búsqueda

# %%
def embed_query(query: str) -> np.ndarray:
    q = "query: " + query
    vec = model.encode(
        [q],
        convert_to_numpy=True,
        normalize_embeddings=True
    ).astype("float32")
    return vec

query_text = "¿De qué se tratan los documentos recuperados?"

query_vec = embed_query(query_text)
query_vec.shape
# Out:
# (1, 768)

# %%
print(embeddings.shape, embeddings.dtype)
# Out:
# (38871, 768) float32

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
# ,  Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# ,Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# ,Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# ,Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.8 MB)
# ,   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 113.8 MB/s eta 0:00:00
# ,Installing collected packages: faiss-cpu
# ,Successfully installed faiss-cpu-1.13.2

# %%
import faiss
import numpy as np

index = faiss.IndexFlatL2(embeddings.shape[1])
index.add(embeddings)

D, I = index.search(query_vec, k=10)

# %% [markdown]
# Obtengo los 5 documentos más similares a mi query

# %%
# Recuperamos los fragmentos más relevantes según la consulta
top_k = 5
D, I = index.search(query_vec, k=top_k)

top_idxs = I.flatten().tolist()
top_passages = chunks_df.iloc[top_idxs].copy()
top_passages["distance"] = D.flatten()
top_passages[["doc_id", "chunk_id", "distance", "text"]].head(10)
# Out:
#        doc_id  chunk_id  distance  \
# 11494    5441        23  0.424097
# 1239      682         3  0.429677
# 24011   11436         6  0.430660
# 15766    7435         9  0.430687
# 9515     4624         1  0.437481
#
#                                                     text
# 11494  eial Convention, Inc., for distribution by the...
# 1239   -------- Introduction & Administrivia --------...
# 24011  he rest of us. The protocol may be changed sli...
# 15766  d finish up the subject for a while. Perhaps y...
# 9515   ----------------------- | | 1 2 | | Select 1 i...

# %%
passages_text = []
for i, row in enumerate(top_passages.itertuples(index=False), 1):
    passages_text.append(f"Fragmento {i}:\n{row.text}")

context_block = "\n\n".join(passages_text)

# %%
prompt = f"""
Eres un asistente que analiza textos.

PREGUNTA DEL USUARIO:
{query_text}

PASAJES (top {top_k}):
{context_block}

"""

# Llamada a Gemini (usando el modelo ya creado)
response = model.generate_content(prompt)

print(response.text)
# Out:
# A continuación, el análisis de los fragmentos recuperados:
# ,
# ,---
# ,
# ,**1) Análisis de cada fragmento:**
# ,
# ,*   **Fragmento 1:**
# ,    Describe la disponibilidad de documentos médicos, incluyendo folletos en español sobre quimioterapia y radioterapia para pacientes con cáncer, distribuidos por el National Cancer Institute. También hace referencia a resúmenes de noticias sobre el SIDA de una publicación médica.
# ,
# ,*   **Fragmento 2:**
# ,    Se trata de la introducción a un documento de Preguntas Frecuentes (FAQ) publicado mensualmente en grupos de noticias de Usenet. Advierte a los lectores sobre la posible obsolescencia de la información y les indica cómo acceder a la versión más reciente a través de sitios de archivo.
# ,
# ,*   **Fragmento 3:**
# ,    El fragmento describe un protocolo de seguridad que involucra "seeds" y agentes de custodia ("escrow agents") transportando discos a agencias. El autor expresa escepticismo sobre su eficacia, insinuando que una entidad como la NSA podría tener ya los algoritmos para anularlo.
# ,
# ,*   **Fragmento 4:**
# ,    Este fragmento es una comunicación donde el remitente sugiere transformar su respuesta en un documento de Preguntas Frecuentes (FAQ) para futuras republicaciones. Ofrece permiso para reorganizar el contenido, pero solicita una copia del FAQ final.
# ,
# ,*   **Fragmento 5:**
# ,    Este fragmento presenta un sistema de menú interactivo, probablemente para un servicio automatizado como AnswerFAX. Permite al usuario elegir entre obtener una explicación, ordenar un documento o explorar diferentes catálogos de productos y notas de aplicación.
# ,
# ,---
# ,
# ,**Síntesis Comparativa:**
# ,Los fragmentos 1, 2, 4 y 5 abordan la temática de los documentos y su gestión, ya sea su distribución (Fragmento 1), acceso y actualización (Fragmento 2), creación y republicación (Fragmento 4), o sistemas de pedido (Fragmento 5). Todos ellos se centran en la organización, disponibilidad y acceso a la información escrita. El Fragmento 3 se distingue por centrarse en un protocolo de seguridad criptográfico y su cuestionable eficacia, sin relación directa con la gestión documental o la distribución de información al público.
# ,
# ,---
# ,
# ,**2) Resumen global:**
# ,
# ,Los documentos recuperados giran predominantemente en torno a la gestión y acceso de información y documentos en diversos formatos. Incluyen la descripción de publicaciones médicas disponibles para pacientes, como guías de quimioterapia y radioterapia (Fragmento 1), y explican cómo acceder y mantener actualizados documentos de Preguntas Frecuentes (FAQ) en plataformas como Usenet (Fragmentos 2 y 4). También se describe un sistema interactivo para solicitar documentos y explorar catálogos de productos (Fragmento 5). Un pasaje (Fragmento 3) se desmarca al abordar un protocolo de seguridad y su posible vulnerabilidad, sin conexión directa con la difusión o administración de documentos. En conjunto, los textos reflejan distintas facetas de la organización y disponibilidad de la información.
